# %%
#AREA OF RECTANGLE
len=int(input('enter the length'))
bre=int(input('enter the breath'))
print(f'area of rectangle is {len*bre}')
#SIMPLE INTERST
p=int(input('enter the principle amount'))
r=int(input('enter the rate'))
t=int(input('enter the time'))
print(f'simple interest is {p*r*t/100}')
#CONVERT CELSIUS TO FAHRENHEIT
cel=int(input('enter the temperature in celsius'))
print(f'temperature in fahrenheit is {cel*9/5+32}')
#AVERAGE OF THREE NUMBERS
NUM1=int(input('enter the first number'))
NUM2=int(input('enter the second number'))
NUM3=int(input('enter the third number'))
print(f'average of three numbers is {(NUM1+NUM2+NUM3)/3}')
#FIND THE SQUARE AND CUBE OF A NUMBER
NUM=int(input('enter the number'))
print(f'square of the number is {NUM**2}')
print(f'cube of the number is {NUM**3}')
#SWAP TWO NUMBERS WITHOUT A THIRD VARIABLE
NUM=int(input('enter the  number'))
NUM1=int(input('enter the number'))
NUM,NUM1=NUM1,NUM
print(f'swapped numbers are {NUM} and {NUM1}')
#CREATING A STUDENT REPORT
NAME=input('enter the name')
ROLL=int(input('enter the roll number'))
max=int(input('enter the maximum marks'))
MATHS=int(input('enter the marks in maths'))
SCIENCE=int(input('enter the marks in science'))
ENGLISH=int(input('enter the marks in english'))
print(f'name is {NAME}/{max}')
print(f'roll number is {ROLL}/{max}')
print(f'marks in maths is {MATHS}/{max}')
print(f'marks in science is {SCIENCE}/{max}')
print(f'marks in english is {ENGLISH}/{max}')
print(f'total marks is {MATHS+SCIENCE+ENGLISH}/{max*3}')
print(f'total percentage ={(MATHS+SCIENCE+ENGLISH)/(max*3)*100}%')
