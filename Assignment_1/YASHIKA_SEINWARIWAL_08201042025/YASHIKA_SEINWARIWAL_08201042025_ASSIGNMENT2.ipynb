# %%
#PRINT NUMBERS FROM 1 TO 10
for i in range (1,10):
  print(i)

#Print first 10 even munbers
for i in range (0,20):
  if i%2==0:
    print(i)

#PRINT MULTIPLICATION TABLE OF ANY NUMBER
num_table = int(input('Enter the number for multiplication table: '))
for i in range (1,11):
  print(f"{num_table} * {i} = {num_table*i}")

#check whather a person is eligible to vote
age=int(input('enter the age '))
if age>=18:
  print('person is eligible to vote')
else:
  print('person is not eligible to vote')


#DISPLAY STUDENT'S GARDE  BASED ON MARKS
marks=int(input('enter the marks'))
if marks>=90:
  print('grade A')
elif marks>=75:
  print('grade B')
elif marks>=65:
  print('grade  print('grade D')
else:
  print('grade F')

#FACTORIAL OF A NUMBER
  num=int(input(' enter a number'))
  factorial=1
  for i in range(1, n + 1):
        factorial*= i
  print('the factorial is ',factorial)

#reversing a number

num=int(input('enter a two digit number'))
first_digit=num//10
second_digit=num%10
reverse_number=second_digit*10+first_digit
print('the reverse number is ',reverse_number)
